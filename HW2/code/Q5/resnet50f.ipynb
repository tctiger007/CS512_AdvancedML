# %%
import importlib.util
import sys
from google.colab import drive

drive.mount('/content/gdrive')

# To add a directory with your code into a list of directories 
# which will be searched for packages
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
sys.path.append('/content/gdrive/My Drive/hw2/code/')
import data_loader

# %%
import torch
import torch.optim as optim
import torch.nn as nn
from torchvision import transforms
from torch.nn import functional as F
import torch.optim as optim
import torch.utils.data as data_utils
from data_loader import get_dataset
import torch.optim as optim
from torch.optim import Adam, SGD, LBFGS
import numpy as np

# %%
batch_size = 256
num_epochs = 1000
max_iters  = 1000
print_iter = 25 # Prints results every n iterations
conv_shapes = [[1,64,128]] #


# Model parameters
input_dim = 128
embed_dim = 64
num_labels = 26
cuda = torch.cuda.is_available()

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
from torchvision import models   
model = models.resnet50(pretrained=True).to(device)
for param in model.parameters():

  param.requires_grad = False

# %%
model.fc = nn.Sequential(
               nn.Linear(2048,896),
               nn.ReLU(inplace=True),
               nn.Linear(896, 26)).to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.fc.parameters())

# %%
#testing
def testing():
    finaltestletteracc =0 
    testpredictedletters,testactualletters=[],[]
    for i_batch, sample in enumerate(test_loader):
        if i_batch%25==0:
          print("Batch=", i_batch)
        test_X = sample[0]
        test_Y = sample[1]
#       print(len(test_X))

        lastflag = (len(test_X)<256)
        if lastflag:
          test_X= test_X.view(len(test_X),1,16,8)
          test_X= test_X.repeat(1,3,1,1)
          test_Y = test_Y.view(len(train_Y),26)
        else:
          test_X= test_X.view(256,1,16,8)
          test_X= test_X.repeat(1,3,1,1)
          test_Y = test_Y.view(256,26)
        
        
        if cuda:
            test_X = test_X.cuda()
            test_Y = test_Y.cuda()

        labels=  torch.max(test_Y, 1)[1]
        
        

        outputs = model(test_X)
        loss = criterion(outputs,labels)

        running_loss = 0.0
        running_corrects = 0
        _, preds = torch.max(outputs, 1)
        testactualletters.extend(labels.tolist())
        testpredictedletters.extend(preds.tolist())
        running_loss += loss.item() * test_X.size(0)
        running_corrects += torch.sum(preds == (labels.data))
        
        epoch_loss = running_loss / len(test_Y)
        epoch_acc = running_corrects.double() / len(test_Y)
        finaltestletteracc = finaltestletteracc + len(test_Y)*epoch_acc
        if i_batch%25==0:
          print("Letter accuracy =",epoch_acc)
    
    wtestingepoc.append(wordaccuracies(testpredictedletters,testactualletters))
    testingepoc.append(finaltestletteracc/len(test))
    print("Testing acc = :",finaltestletteracc/len(test) ) 


#word accuracies function
#gettinig data using DataLoader class , modified code
dataset = get_dataset()

#word accuracies function based on letters, required dataset.nextletter info
def wordaccuracies(pred,actual):
  incorrectwords = 0
  totalwords = 0
  flag = True

  for i in range(len(pred)):

    if pred[i] != actual[i]:
      flag= False
    if dataset.nextletter[split+i] == -1:
      if flag == False:
        incorrectwords+=1
        flag  = True
      totalwords = totalwords+1

  wordaccuracy = 1 - incorrectwords/totalwords
  print("Word accuracy: ", wordaccuracy)
  return wordaccuracy
  print("\n")

# %%
#get data
dataset = get_dataset()

trainingepoc,testingepoc=[],[]
wtrainingepoc,wtestingepoc=[],[]
#split data
split = int(0.5 * len(dataset.data)) # train-test split
train_data, test_data = dataset.data[:split], dataset.data[split:]
train_target, test_target = dataset.target[:split], dataset.target[split:]
    # Convert dataset into torch tensors
train = data_utils.TensorDataset(torch.tensor(train_data).float(), torch.tensor(train_target).long())
test = data_utils.TensorDataset(torch.tensor(test_data).float(), torch.tensor(test_target).long())

# Define train and test loaders
train_loader = data_utils.DataLoader(train,  # dataset to load from
                                         batch_size=batch_size,  # examples per batch (default: 1)
                                         shuffle=True,
                                         sampler=None,  # if a sampling method is specified, `shuffle` must be False
                                         num_workers=5,  # subprocesses to use for sampling
                                         pin_memory=False,  # whether to return an item pinned to GPU
                                         )

test_loader = data_utils.DataLoader(test,  # dataset to load from
                                        batch_size=batch_size,  # examples per batch (default: 1)
                                        shuffle=False,
                                        sampler=None,  # if a sampling method is specified, `shuffle` must be False
                                        num_workers=5,  # subprocesses to use for sampling
                                        pin_memory=False,  # whether to return an item pinned to GPU
                                        )


for i in range(100):
    finaltrainletteracc= 0
    trainpredictedletters,trainactualletters=[],[]
    print("\n  Processing epoch {}".format(i))
    
 #   print('Loaded dataset... ')

    # Now start training
    for i_batch, sample in enumerate(train_loader):
        
        if i_batch%25==0:
          print("Batch=", i_batch)
        train_X = sample[0]
        train_Y = sample[1]

        lastflag = (len(train_X)<256)
        if lastflag:
          train_X= train_X.view(len(train_X),1,16,8)
          train_X= train_X.repeat(1,3,1,1)
          train_Y = train_Y.view(len(train_Y),26)
        else:
          train_X= train_X.view(256,1,16,8)
          train_X= train_X.repeat(1,3,1,1)
          train_Y = train_Y.view(256,26)
        
        if cuda:
            train_X = train_X.cuda()
            train_Y = train_Y.cuda()
        
        labels=  torch.max(train_Y, 1)[1]

        
        
        optimizer.zero_grad()
        outputs = model(train_X)         
        loss = criterion(outputs,labels)
        loss.backward()

        #outputs = model(train_X)
        #loss = criterion(outputs, labels)

        running_loss = 0.0
        running_corrects = 0

        optimizer.step()
        _, preds = torch.max(outputs, 1)
        
        
        trainactualletters.extend(labels.tolist())
        trainpredictedletters.extend(preds.tolist())

        running_loss += loss.item() * train_X.size(0)
        running_corrects += torch.sum(preds == (labels).data)

        epoch_loss = running_loss / len(train_Y)
        epoch_acc = running_corrects.double() / len(train_Y)

        if i_batch%25==0:
          print("Letter accuracy =",epoch_acc)
        finaltrainletteracc = finaltrainletteracc + len(train_X)*epoch_acc
    
    wtrainingepoc.append(wordaccuracies(trainpredictedletters,trainactualletters))
    trainingepoc.append(finaltrainletteracc/len(train))
    print("Training acc = :",finaltrainletteracc/len(train) )
    testing()
# Out:
#   Processing epoch 0
# Batch= 0
# Letter accuracy = tensor(0.0234, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.3438, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.3555, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.4375, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.4844, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.07714958775029446
# Training acc = : tensor(0.3650, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.4727, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.4219, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5078, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.3750, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.4375, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.07862190812720848
# Testing acc = : tensor(0.4363, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 1
# Batch= 0
# Letter accuracy = tensor(0.4492, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.4023, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5234, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.4961, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5195, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.10865724381625441
# Training acc = : tensor(0.4761, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5273, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.4688, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5234, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.4648, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.4922, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.09481743227326267
# Testing acc = : tensor(0.4835, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 2
# Batch= 0
# Letter accuracy = tensor(0.5000, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.4883, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5273, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5312, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5312, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.11454652532391052
# Training acc = : tensor(0.5093, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5391, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.4883, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5586, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5000, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5352, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.09923439340400475
# Testing acc = : tensor(0.5033, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 3
# Batch= 0
# Letter accuracy = tensor(0.5000, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.4609, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5547, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5312, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5938, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13515901060070667
# Training acc = : tensor(0.5308, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5195, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.4883, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5352, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.4805, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5156, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.091283863368669
# Testing acc = : tensor(0.4900, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 4
# Batch= 0
# Letter accuracy = tensor(0.5078, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5391, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6016, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5664, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5391, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13545347467608948
# Training acc = : tensor(0.5500, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5430, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.4766, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5625, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.4922, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5312, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.11189634864546527
# Testing acc = : tensor(0.5154, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 5
# Batch= 0
# Letter accuracy = tensor(0.5391, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5742, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5938, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5742, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5898, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.14958775029446403
# Training acc = : tensor(0.5713, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5508, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.4766, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5547, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5078, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5742, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.12161366313309774
# Testing acc = : tensor(0.5232, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 6
# Batch= 0
# Letter accuracy = tensor(0.5703, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5469, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5781, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5586, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5508, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.14899882214369842
# Training acc = : tensor(0.5790, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5742, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5117, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5977, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5078, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5508, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.10482921083627794
# Testing acc = : tensor(0.5224, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 7
# Batch= 0
# Letter accuracy = tensor(0.6094, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5977, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6094, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5742, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6250, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.1816843345111896
# Training acc = : tensor(0.5988, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5820, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5156, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5938, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5117, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5859, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.12926972909305068
# Testing acc = : tensor(0.5448, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 8
# Batch= 0
# Letter accuracy = tensor(0.5898, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.6094, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6992, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.6445, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6367, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.17785630153121323
# Training acc = : tensor(0.6155, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5664, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.4805, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6055, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5352, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5742, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.12396937573616018
# Testing acc = : tensor(0.5374, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 9
# Batch= 0
# Letter accuracy = tensor(0.6445, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5859, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6836, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.6406, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5938, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.18404004711425204
# Training acc = : tensor(0.6189, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5430, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5117, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5547, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5312, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6172, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13515901060070667
# Testing acc = : tensor(0.5412, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 10
# Batch= 0
# Letter accuracy = tensor(0.6211, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.6289, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6562, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5820, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6523, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.1925795053003534
# Training acc = : tensor(0.6321, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5898, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5156, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6172, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5391, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6055, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13221436984687873
# Testing acc = : tensor(0.5429, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 11
# Batch= 0
# Letter accuracy = tensor(0.6758, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.6055, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6836, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.6289, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6016, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.18669022379269729
# Training acc = : tensor(0.6424, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5703, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5391, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6211, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5586, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6016, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.12720848056537104
# Testing acc = : tensor(0.5471, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 12
# Batch= 0
# Letter accuracy = tensor(0.6328, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.6758, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6914, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.7031, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6875, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.2037691401648999
# Training acc = : tensor(0.6556, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5938, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5312, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6055, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5703, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6094, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13427561837455826
# Testing acc = : tensor(0.5496, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 13
# Batch= 0
# Letter accuracy = tensor(0.6406, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7031, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6445, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.7070, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6562, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.2093639575971732
# Training acc = : tensor(0.6679, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5742, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5312, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5703, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5820, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5977, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13457008244994106
# Testing acc = : tensor(0.5614, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 14
# Batch= 0
# Letter accuracy = tensor(0.6953, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.6602, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6523, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.6094, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6562, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.2164310954063604
# Training acc = : tensor(0.6666, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5547, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5273, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6016, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5273, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5703, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.1251472320376914
# Testing acc = : tensor(0.5492, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 15
# Batch= 0
# Letter accuracy = tensor(0.6562, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.6836, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.7188, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.6172, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.7227, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.22290930506478213
# Training acc = : tensor(0.6751, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5742, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5352, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6094, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5586, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5898, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.125736160188457
# Testing acc = : tensor(0.5517, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 16
# Batch= 0
# Letter accuracy = tensor(0.6680, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7500, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6680, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.7148, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6680, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.233510011778563
# Training acc = : tensor(0.6810, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5742, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5039, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6016, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5469, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5977, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13398115429917545
# Testing acc = : tensor(0.5516, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 17
# Batch= 0
# Letter accuracy = tensor(0.7031, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.6953, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6914, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.6836, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6406, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.24263839811542987
# Training acc = : tensor(0.6950, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.6250, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5078, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6055, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5586, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5195, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.12750294464075385
# Testing acc = : tensor(0.5463, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 18
# Batch= 0
# Letter accuracy = tensor(0.6914, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.6758, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.7188, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.7461, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.7070, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.2385159010600707
# Training acc = : tensor(0.6995, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.6172, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5039, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6250, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5547, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6055, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.12279151943462896
# Testing acc = : tensor(0.5503, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 19
# Batch= 0
# Letter accuracy = tensor(0.7422, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.6758, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.7148, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.6992, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.7070, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.23939929328621912
# Training acc = : tensor(0.7064, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5898, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5195, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6133, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5781, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6211, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13457008244994106
# Testing acc = : tensor(0.5538, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 20
# Batch= 0
# Letter accuracy = tensor(0.7188, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7227, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6797, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.6445, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6914, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.24352179034157828
# Training acc = : tensor(0.7065, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5781, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5234, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6172, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5703, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5977, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.12956419316843348
# Testing acc = : tensor(0.5545, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 21
# Batch= 0
# Letter accuracy = tensor(0.7109, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.6602, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.7266, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.7227, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.7461, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.25294464075382805
# Training acc = : tensor(0.7176, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5781, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5430, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6133, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5781, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5898, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.125736160188457
# Testing acc = : tensor(0.5509, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 22
# Batch= 0
# Letter accuracy = tensor(0.7422, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7227, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6797, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.6836, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6641, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.25
# Training acc = : tensor(0.7169, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5859, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5156, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6055, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5312, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5938, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.12838633686690226
# Testing acc = : tensor(0.5540, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 23
# Batch= 0
# Letter accuracy = tensor(0.7734, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7031, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6992, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.7109, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6914, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.26884570082449943
# Training acc = : tensor(0.7287, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5547, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5469, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5625, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5469, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5586, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13898704358068315
# Testing acc = : tensor(0.5460, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 24
# Batch= 0
# Letter accuracy = tensor(0.7578, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7070, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.7578, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.7227, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6875, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.2714958775029447
# Training acc = : tensor(0.7353, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5625, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5156, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5781, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5273, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5898, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13191990577149593
# Testing acc = : tensor(0.5433, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 25
# Batch= 0
# Letter accuracy = tensor(0.7227, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7109, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.7461, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.7578, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.7656, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.28180212014134276
# Training acc = : tensor(0.7431, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5938, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5273, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5859, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5703, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5977, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.1366313309776207
# Testing acc = : tensor(0.5544, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 26
# Batch= 0
# Letter accuracy = tensor(0.7930, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7695, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.7578, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.7461, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.7656, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.28062426383981154
# Training acc = : tensor(0.7457, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5547, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5156, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5781, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5664, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5977, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13545347467608948
# Testing acc = : tensor(0.5544, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 27
# Batch= 0
# Letter accuracy = tensor(0.7148, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7695, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.7305, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.7422, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.7773, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.2879858657243817
# Training acc = : tensor(0.7426, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5898, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5000, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6133, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5664, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5781, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.1304475853945819
# Testing acc = : tensor(0.5518, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 28
# Batch= 0
# Letter accuracy = tensor(0.7500, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7500, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.7578, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.7383, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.7969, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.290341578327444
# Training acc = : tensor(0.7544, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5898, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5352, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5938, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5781, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5703, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.1301531213191991
# Testing acc = : tensor(0.5580, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 29
# Batch= 0
# Letter accuracy = tensor(0.7578, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7930, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8047, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8164, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.7891, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.2944640753828033
# Training acc = : tensor(0.7583, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5977, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5469, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5703, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5586, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5781, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13250883392226154
# Testing acc = : tensor(0.5517, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 30
# Batch= 0
# Letter accuracy = tensor(0.7695, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7578, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.7266, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.7617, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6719, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.2912249705535924
# Training acc = : tensor(0.7534, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5703, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5195, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6094, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5859, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5977, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13810365135453473
# Testing acc = : tensor(0.5583, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 31
# Batch= 0
# Letter accuracy = tensor(0.7812, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7695, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.7930, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.7695, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.7656, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.30859835100117783
# Training acc = : tensor(0.7667, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5469, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5430, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5703, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5742, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5742, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.1360424028268551
# Testing acc = : tensor(0.5502, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 32
# Batch= 0
# Letter accuracy = tensor(0.8203, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.8242, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.7852, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8203, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.7773, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.308303886925795
# Training acc = : tensor(0.7665, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5820, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5234, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5977, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5586, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5938, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.1304475853945819
# Testing acc = : tensor(0.5491, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 33
# Batch= 0
# Letter accuracy = tensor(0.7500, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7969, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8203, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.7930, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.7344, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.3124263839811543
# Training acc = : tensor(0.7706, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5742, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5117, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5703, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5430, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5977, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13368669022379265
# Testing acc = : tensor(0.5519, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 34
# Batch= 0
# Letter accuracy = tensor(0.7773, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.8125, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.7852, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.7930, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.7930, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.32155477031802115
# Training acc = : tensor(0.7770, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5820, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5312, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5625, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5703, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5781, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.1369257950530035
# Testing acc = : tensor(0.5502, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 35
# Batch= 0
# Letter accuracy = tensor(0.7070, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7812, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8047, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8008, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.7656, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.30388692579505305
# Training acc = : tensor(0.7731, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5664, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5312, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5586, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5508, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5898, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.1254416961130742
# Testing acc = : tensor(0.5489, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 36
# Batch= 0
# Letter accuracy = tensor(0.7773, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7227, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8164, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.7422, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.7969, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.3309776207302709
# Training acc = : tensor(0.7793, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5742, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5156, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5586, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5820, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6094, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13368669022379265
# Testing acc = : tensor(0.5537, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 37
# Batch= 0
# Letter accuracy = tensor(0.8008, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.8086, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.7500, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.7383, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.7812, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.31507656065959955
# Training acc = : tensor(0.7793, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5977, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5234, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5391, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5547, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5508, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.1298586572438163
# Testing acc = : tensor(0.5451, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 38
# Batch= 0
# Letter accuracy = tensor(0.7695, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.8008, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.7930, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.7500, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.8047, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.31507656065959955
# Training acc = : tensor(0.7788, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5547, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5234, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5352, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5625, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5781, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.1310365135453475
# Testing acc = : tensor(0.5472, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 39
# Batch= 0
# Letter accuracy = tensor(0.7578, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7969, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.7891, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8086, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.7812, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.3295053003533569
# Training acc = : tensor(0.7882, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5742, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5117, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5938, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5391, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6172, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13339222614840984
# Testing acc = : tensor(0.5547, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 40
# Batch= 0
# Letter accuracy = tensor(0.7656, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7461, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8242, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.7969, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.7852, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.3362779740871613
# Training acc = : tensor(0.7892, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5703, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5195, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5781, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5352, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5664, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13457008244994106
# Testing acc = : tensor(0.5445, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 41
# Batch= 0
# Letter accuracy = tensor(0.8164, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7852, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.7656, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8203, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.8047, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.3530624263839811
# Training acc = : tensor(0.7963, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5391, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5352, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5859, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5352, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5781, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.1301531213191991
# Testing acc = : tensor(0.5501, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 42
# Batch= 0
# Letter accuracy = tensor(0.7734, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7969, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.7539, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8438, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.7852, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.3409893992932862
# Training acc = : tensor(0.7932, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5703, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5078, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5898, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5781, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5742, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13869257950530034
# Testing acc = : tensor(0.5541, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 43
# Batch= 0
# Letter accuracy = tensor(0.7266, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7773, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8047, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8125, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.8203, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.35011778563015317
# Training acc = : tensor(0.8009, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5586, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5547, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5586, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5508, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5898, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.12809187279151946
# Testing acc = : tensor(0.5508, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 44
# Batch= 0
# Letter accuracy = tensor(0.8203, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7734, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.7891, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8086, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.7891, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.3527679623085983
# Training acc = : tensor(0.7986, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5586, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.4961, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5859, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5547, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5820, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13987043580683156
# Testing acc = : tensor(0.5524, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 45
# Batch= 0
# Letter accuracy = tensor(0.8203, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.7734, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8047, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8281, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.8242, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.3527679623085983
# Training acc = : tensor(0.8018, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5625, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5312, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5781, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5898, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6016, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.1369257950530035
# Testing acc = : tensor(0.5550, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 46
# Batch= 0
# ...
# Batch= 50
# Letter accuracy = tensor(0.5938, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5859, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6133, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.1298586572438163
# Testing acc = : tensor(0.5515, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 85
# Batch= 0
# Letter accuracy = tensor(0.8320, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.8477, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8633, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8906, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.8555, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.432567726737338
# Training acc = : tensor(0.8487, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5586, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5195, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5781, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5195, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6133, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.1363368669022379
# Testing acc = : tensor(0.5551, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 86
# Batch= 0
# Letter accuracy = tensor(0.8008, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.8516, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8906, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8438, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.8438, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.43904593639575973
# Training acc = : tensor(0.8556, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.6055, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5039, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6016, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5469, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5820, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.12956419316843348
# Testing acc = : tensor(0.5501, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 87
# Batch= 0
# Letter accuracy = tensor(0.8125, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.8789, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8398, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8633, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.8164, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.42903415783274446
# Training acc = : tensor(0.8507, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5703, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5000, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6055, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5586, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5859, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.12632508833922262
# Testing acc = : tensor(0.5481, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 88
# Batch= 0
# Letter accuracy = tensor(0.8398, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.8828, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8320, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.9219, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.8203, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.42756183745583043
# Training acc = : tensor(0.8477, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5820, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5195, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6016, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5703, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6055, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.12897526501766787
# Testing acc = : tensor(0.5499, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 89
# Batch= 0
# Letter accuracy = tensor(0.8477, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.8672, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8984, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8516, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.8789, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.43580683156654887
# Training acc = : tensor(0.8562, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5781, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5352, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5898, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5508, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5742, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.1298586572438163
# Testing acc = : tensor(0.5482, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 90
# Batch= 0
# Letter accuracy = tensor(0.8750, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.8828, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8281, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8477, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.8398, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.44140164899882217
# Training acc = : tensor(0.8568, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5859, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5273, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5859, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5469, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5977, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.1304475853945819
# Testing acc = : tensor(0.5581, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 91
# Batch= 0
# Letter accuracy = tensor(0.8672, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.8867, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8438, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8438, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.8242, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.43904593639575973
# Training acc = : tensor(0.8557, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5742, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5195, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5938, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5977, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5898, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13368669022379265
# Testing acc = : tensor(0.5537, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 92
# Batch= 0
# Letter accuracy = tensor(0.8398, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.8789, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8516, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.9062, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.8320, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.42815076560659604
# Training acc = : tensor(0.8510, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5898, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5352, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6094, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5938, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5938, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.12661955241460543
# Testing acc = : tensor(0.5527, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 93
# Batch= 0
# Letter accuracy = tensor(0.8633, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.8281, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8633, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8320, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.8477, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.4387514723203769
# Training acc = : tensor(0.8563, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5742, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5391, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6016, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5508, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.6016, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13162544169611312
# Testing acc = : tensor(0.5594, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 94
# Batch= 0
# Letter accuracy = tensor(0.8789, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.8711, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8359, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8438, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.8203, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.4496466431095406
# Training acc = : tensor(0.8565, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5547, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5430, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.6016, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5742, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5898, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13486454652532387
# Testing acc = : tensor(0.5525, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 95
# Batch= 0
# Letter accuracy = tensor(0.8320, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.8672, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8672, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8359, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.8203, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.4372791519434629
# Training acc = : tensor(0.8525, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5898, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5312, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5938, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5703, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5938, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.13309776207302704
# Testing acc = : tensor(0.5501, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 96
# Batch= 0
# Letter accuracy = tensor(0.8711, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.8516, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8594, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8711, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.8906, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.4652532391048292
# Training acc = : tensor(0.8617, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5664, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5195, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5898, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5547, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5664, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.12338044758539457
# Testing acc = : tensor(0.5471, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 97
# Batch= 0
# Letter accuracy = tensor(0.8359, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.8359, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8828, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8633, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.8594, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.4599528857479388
# Training acc = : tensor(0.8632, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5742, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5312, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5859, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5664, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5938, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.1301531213191991
# Testing acc = : tensor(0.5509, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 98
# Batch= 0
# Letter accuracy = tensor(0.8906, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.8516, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8633, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8281, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.8516, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.4378680800942285
# Training acc = : tensor(0.8583, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5664, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5000, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5977, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5273, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5977, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.12779740871613665
# Testing acc = : tensor(0.5550, device='cuda:0', dtype=torch.float64)
#
#   Processing epoch 99
# Batch= 0
# Letter accuracy = tensor(0.7891, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.8555, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.8711, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.8633, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.8438, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.443168433451119
# Training acc = : tensor(0.8593, device='cuda:0', dtype=torch.float64)
# Batch= 0
# Letter accuracy = tensor(0.5664, device='cuda:0', dtype=torch.float64)
# Batch= 25
# Letter accuracy = tensor(0.5117, device='cuda:0', dtype=torch.float64)
# Batch= 50
# Letter accuracy = tensor(0.5859, device='cuda:0', dtype=torch.float64)
# Batch= 75
# Letter accuracy = tensor(0.5547, device='cuda:0', dtype=torch.float64)
# Batch= 100
# Letter accuracy = tensor(0.5820, device='cuda:0', dtype=torch.float64)
# Word accuracy:  0.12720848056537104
# Testing acc = : tensor(0.5442, device='cuda:0', dtype=torch.float64)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
# Data
x= [x for x in range(100)]
y1 = trainingepoc
y2 = testingepoc
y3 = wtrainingepoc
y4 = wtestingepoc

w = 10
h = 8
d = 100
plt.figure(figsize=(w, h), dpi=d)

plt.plot(x, y1, color='red', linewidth=2,  label="Training Letter Acc")
plt.plot(x, y2, color='red', linewidth=2,linestyle='dashed',   label="Testing Letter Acc")
plt.plot(x, y3, color='green', linewidth=1, label="Training Word Acc")
plt.plot(x, y4, color='green', linewidth=1,linestyle='dashed',  label="Training Word Acc")
plt.legend()

plt.savefig("accuracies.png")

# %%
max(testingepoc)
# Out:
# tensor(0.5500, device='cuda:0', dtype=torch.float64)

# %%
x= [float(x) for x in wtestingepoc]

# %%
print(x)
# Out:
# [0.07862190812720848, 0.09481743227326267, 0.09923439340400475, 0.091283863368669, 0.11189634864546527, 0.12161366313309774, 0.10482921083627794, 0.12926972909305068, 0.12396937573616018, 0.13515901060070667, 0.13221436984687873, 0.12720848056537104, 0.13427561837455826, 0.13457008244994106, 0.1251472320376914, 0.125736160188457, 0.13398115429917545, 0.12750294464075385, 0.12279151943462896, 0.13457008244994106, 0.12956419316843348, 0.125736160188457, 0.12838633686690226, 0.13898704358068315, 0.13191990577149593, 0.1366313309776207, 0.13545347467608948, 0.1304475853945819, 0.1301531213191991, 0.13250883392226154, 0.13810365135453473, 0.1360424028268551, 0.1304475853945819, 0.13368669022379265, 0.1369257950530035, 0.1254416961130742, 0.13368669022379265, 0.1298586572438163, 0.1310365135453475, 0.13339222614840984, 0.13457008244994106, 0.1301531213191991, 0.13869257950530034, 0.12809187279151946, 0.13987043580683156, 0.1369257950530035, 0.13398115429917545, 0.1304475853945819, 0.14016489988221437, 0.13457008244994106, 0.13545347467608948, 0.13221436984687873, 0.12956419316843348, 0.12779740871613665, 0.13574793875147229, 0.1298586572438163, 0.12868080094228507, 0.13368669022379265, 0.1301531213191991, 0.13486454652532387, 0.13427561837455826, 0.1310365135453475, 0.12338044758539457, 0.1304475853945819, 0.1248527679623086, 0.13162544169611312, 0.12661955241460543, 0.1310365135453475, 0.1301531213191991, 0.1304475853945819, 0.13751472320376912, 0.12897526501766787, 0.13368669022379265, 0.13162544169611312, 0.13339222614840984, 0.13368669022379265, 0.13368669022379265, 0.1248527679623086, 0.12897526501766787, 0.1366313309776207, 0.1248527679623086, 0.13309776207302704, 0.125736160188457, 0.13280329799764434, 0.1298586572438163, 0.1363368669022379, 0.12956419316843348, 0.12632508833922262, 0.12897526501766787, 0.1298586572438163, 0.1304475853945819, 0.13368669022379265, 0.12661955241460543, 0.13162544169611312, 0.13486454652532387, 0.13309776207302704, 0.12338044758539457, 0.1301531213191991, 0.12779740871613665, 0.12720848056537104]
